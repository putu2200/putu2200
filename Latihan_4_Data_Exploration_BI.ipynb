# %% [markdown]
# <a href="https://colab.research.google.com/github/putu2200/putu2200/blob/main/Latihan_4_Data_Exploration_BI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
cpu_usage = [
    [2, 2, 4, 2, 4, 1, 1, 4, 4, 12, 22, 23,45, 9, 33, 56, 23, 40, 21, 6, 6, 2, 2, 3], # Monday
    [1, 2, 3, 2, 3, 2, 3, 2, 7, 22, 45, 44,33, 9, 23, 19, 33, 56, 12, 2, 3, 1, 2, 2], # Tuesday
    [2, 3, 1, 2, 4, 4, 2, 2, 1, 2, 5, 31,54, 7, 6, 34, 68, 34, 49, 6, 6, 2, 2, 3], # Wednesday
    [1, 2, 3, 2, 4, 1, 2, 4, 1, 17, 24, 18,41, 3, 44, 42, 12, 36, 41, 2, 2, 4, 2, 4], # Thursday
    [4, 1, 2, 2, 3, 2, 5, 1, 2, 12, 33, 27,43, 8, 38, 53, 29, 45, 39, 3, 1, 1, 3, 4], # Friday
    [2, 3, 1, 2, 2, 5, 2, 8, 4, 2, 3,1, 5, 1, 2, 3, 2, 6, 1, 2, 2, 1, 4, 3], # Saturday
    [1, 2, 3, 1, 1, 3, 4, 2, 3, 1, 2,2, 5, 3, 2, 1, 4, 2, 45, 26, 33, 2, 2, 1], # Sunday
]
labels=["Mon","Tue","Wed","Thu","Fri","Sat","Sun"]
for day in range(len(cpu_usage)):
    plt.plot(np.arange(24),cpu_usage[day],"--o",label=labels[day],linewidth=.4,markersize=4)
plt.xticks(np.arange(24))
plt.legend(loc="best")
plt.xlabel('hour')
plt.ylabel('cpu usage')
plt.show()
# Out:
# <div id='00d326ee-d799-4ff4-9ec0-05d7e7617ee7'></div>

# %% [markdown]
# ![1665274972235_cc.png](data:image/png;base64,...)
